# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_set = pd.read_csv(
    '/Users/zolboo/Desktop/bachelor/employementAnalysis/project/2022-04-08adScrape_cleaned.csv', sep='\t', error_bad_lines=False)
print(len(data_set))
# Out:
# /var/folders/3c/k3xnqw5d1z950nc14nqn2lk00000gn/T/ipykernel_11765/2739621480.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data_set = pd.read_csv(
# b'Skipping line 9169: expected 1 fields, saw 6\nSkipping line 9170: expected 1 fields, saw 19\nSkipping line 9171: expected 1 fields, saw 19\nSkipping line 9172: expected 1 fields, saw 19\nSkipping line 9173: expected 1 fields, saw 19\nSkipping line 9174: expected 1 fields, saw 13\n'
# 9519

# %%
sns.scatterplot(data=data_set, x="type", y="minSalary", hue="district",style="district")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
dSet = data_set [(data_set.type == 'Бүтэн цагийн') | (data_set.type == 'Гэрээт/ Зөвлөх') | (data_set.type == 'Ээлжийн') | (data_set.type == 'Цагийн') | (data_set.type == 'Улирлаар')]
sns.histplot(data=dSet, x='type', height = 10, hue = 'district')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/zolboo/Desktop/bachelor/employementAnalysis/project/data_vis.ipynb Cell 7' in <module>
# ----> <a href='vscode-notebook-cell:/Users/zolboo/Desktop/bachelor/employementAnalysis/project/data_vis.ipynb#ch0000006?line=0'>1</a> dSet = data_set [(data_set.type == 'Бүтэн цагийн') | (data_set.type == 'Гэрээт/ Зөвлөх') | (data_set.type == 'Ээлжийн') | (data_set.type == 'Цагийн') | (data_set.type == 'Улирлаар')]
#       <a href='vscode-notebook-cell:/Users/zolboo/Desktop/bachelor/employementAnalysis/project/data_vis.ipynb#ch0000006?line=1'>2</a> sns.histplot(data=dSet, x='type', height = 10, hue = 'district')
#
# NameError: name 'data_set' is not defined

# %%
dSet = data_set [(data_set.type == 'Цагийн') | (data_set.type == 'Гэрээт/ Зөвлөх') | (data_set.type == 'Ээлжийн') | (data_set.type == 'Бүтэн цагийн') | (data_set.type == 'Улирлаар')]
sns.displot(data=dSet, x="type", hue="district", height=10, kde=True)

# %%
sns.displot(data=data_set, x="level", hue="city", height=15, kde=True)

# %%
sns.histplot(data=data_set, x='city', stat='proportion')
# Out:
# <AxesSubplot:xlabel='city', ylabel='Proportion'>
